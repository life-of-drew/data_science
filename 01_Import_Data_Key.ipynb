# %% [markdown]
# <a href="https://colab.research.google.com/github/life-of-drew/data_science/blob/main/01_Import_Data_Key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Import Data in Python

# %% [markdown]
# ## Learning Objectives
# One of the reasons why Python is such a popular programming language for machine learning is because it supports some very powerful and easy to use packages which are purpose-built for data analysis. One of these packages is the **pandas** package. In this exercise, you will get a brief introduction to the pandas package and how to import data using functions provided by the pandas package. By the end of this tutorial, you will have learned:
#
# + what a pandas Series is
# + what a pandas DataFrame is
# + how to import data from a CSV file
# + how to import data from an Excel file

# %% [markdown]
# ## The pandas Package

# %%
import pandas as pd

# %% [markdown]
# ## The pandas Series

# %%
members = ["Brunei", "Cambodia", "Indonesia", "Laos", "Malaysia", "Myanmar",
           "Philippines", "Singapore", "Thailand", "Vietnam"]

# %%
asean = pd.Series(members)
asean
# Out:
# 0         Brunei
# 1       Cambodia
# 2      Indonesia
# 3           Laos
# 4       Malaysia
# 5        Myanmar
# 6    Philippines
# 7      Singapore
# 8       Thailand
# 9        Vietnam
# dtype: object

# %% [markdown]
# ## The pandas DataFrame

# %%
asean_data = {
    "Brunei": {
        "Capital": "Bandar Seri Begawan",
        "GDP (USD Billion)": 15.3,
        "Population (Millions)": 0.45
    },
    "Cambodia": {
        "Capital": "Phnom Penh",
        "GDP (USD Billion)": 32.5,
        "Population (Millions)": 17.1
    },
    "Indonesia": {
        "Capital": "Jakarta",
        "GDP (USD Billion)": 1390,
        "Population (Millions)": 277
    },
    "Laos": {
        "Capital": "Vientiane",
        "GDP (USD Billion)": 18.4,
        "Population (Millions)": 7.5
    },
    "Malaysia": {
        "Capital": "Kuala Lumpur",
        "GDP (USD Billion)": 440,
        "Population (Millions)": 34.3
    },
    "Myanmar": {
        "Capital": "Naypyidaw",
        "GDP (USD Billion)": 65,
        "Population (Millions)": 55.2
    },
    "Philippines": {
        "Capital": "Manila",
        "GDP (USD Billion)": 440,
        "Population (Millions)": 117.3
    },
    "Singapore": {
        "Capital": "Singapore",
        "GDP (USD Billion)": 514,
        "Population (Millions)": 5.9
    },
    "Thailand": {
        "Capital": "Bangkok",
        "GDP (USD Billion)": 570,
        "Population (Millions)": 71.6
    },
    "Vietnam": {
        "Capital": "Hanoi",
        "GDP (USD Billion)": 430,
        "Population (Millions)": 100.3
    }
}

asean2 = pd.DataFrame(asean_data)
asean2
# Out:
#                                     Brunei    Cambodia Indonesia       Laos  \
# Capital                Bandar Seri Begawan  Phnom Penh   Jakarta  Vientiane
# GDP (USD Billion)                     15.3        32.5      1390       18.4
# Population (Millions)                 0.45        17.1       277        7.5
#
#                            Malaysia    Myanmar Philippines  Singapore  \
# Capital                Kuala Lumpur  Naypyidaw      Manila  Singapore
# GDP (USD Billion)               440         65         440        514
# Population (Millions)          34.3       55.2       117.3        5.9
#
#                       Thailand Vietnam
# Capital                Bangkok   Hanoi
# GDP (USD Billion)          570     430
# Population (Millions)     71.6   100.3

# %% [markdown]
# ## How to import data from a CSV file

# %%
asean_data3 = pd.read_csv("/content/asean_data.csv")
asean_data3.head()
# Out:
#      Country              Capital  GDP (USD Billion)  Population (Millions)
# 0     Brunei  Bandar Seri Begawan               15.3                   0.45
# 1   Cambodia           Phnom Penh               32.5                  17.10
# 2  Indonesia              Jakarta             1390.0                 277.00
# 3       Laos            Vientiane               18.4                   7.50
# 4   Malaysia         Kuala Lumpur              440.0                  34.30

# %% [markdown]
# ## How to import data from an Excel file

# %%
asean_data4 = pd.read_excel("/content/asean_data.xlsx")
asean_data4
# Out:
#        Country              Capital  GDP (USD Billion)  Population (Millions)
# 0       Brunei  Bandar Seri Begawan               15.3                   0.45
# 1     Cambodia           Phnom Penh               32.5                  17.10
# 2    Indonesia              Jakarta             1390.0                 277.00
# 3         Laos            Vientiane               18.4                   7.50
# 4     Malaysia         Kuala Lumpur              440.0                  34.30
# 5      Myanmar            Naypyidaw               65.0                  55.20
# 6  Philippines               Manila              440.0                 117.30
# 7    Singapore            Singapore              514.0                   5.90
# 8     Thailand              Bangkok              570.0                  71.60
# 9      Vietnam                Hanoi              430.0                 100.30
